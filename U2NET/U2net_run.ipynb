# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !nvidia-smi
# Out:
# Sat Jan 14 17:03:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
##  2.Navigate to the directory where your python script(file.py) is located using the command
# %cd /content/drive/MyDrive/U2NET
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/U2NET'
# /content

# %%
# <xx.x> - CUDA version number
# module load cuda-11.2

# %%
# !git clone https://github.com/NathanUA/U-2-Net.git
# Out:
# fatal: destination path 'U-2-Net' already exists and is not an empty directory.

# %%
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/drive/MyDrive/U2NET/U-2-Net/saved_models/u2net_portrait
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/U2NET/U-2-Net/saved_models/u2net_portrait'
# /content/drive/.shortcut-targets-by-id/16oEmLwt5HAKi0B2c65DlDnjhOWAtPSt7/U2NET

# %%
# !gdown https://drive.google.com/uc?id=1ao1ovG1Qtx4b7EoskHXmi2E9rp5CHLcZ

# %%
# %cd /content/drive/MyDrive/U2NET/U-2-Net
# Out:
# /content/drive/MyDrive/U2NET/U-2-Net

# %%
# !python u2net_train.py
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# ---
# train images:  2600
# train labels:  2600
# ---
# ---define optimizer...
# ---start training...
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:3734: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# l0: 0.699836, l1: 0.696572, l2: 0.780444, l3: 0.739770, l4: 0.606362, l5: 0.749633, l6: 0.751300
#
# [epoch:   1/  2, batch:    12/ 2600, ite: 1] train loss: 5.023917, tar: 0.699836
# ...

# %%
# %cd /content/drive/MyDrive/U2NET/U-2-Net
# Out:
# /content/drive/MyDrive/U2NET/U-2-Net

# %%
# !python u2net_test.py
# Out:
# ['/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/0002-01.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/0003.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/bike.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/boat.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/girl.png', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/hockey.png', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/horse.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/im_01.png', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/ISIC_0024319.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/ISIC_0024343.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/ISIC_0024347.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/ISIC_0024320.jpg', '/content/drive/MyDrive/U2NET/U-2-Net/test_data/test_images/ISIC_0024358.jpg', '/content/drive/MyDrive/U2N
# ...
